# %%
import pandas as pd

from datasets import load_dataset
import matplotlib.pyplot as plt

import numpy as np

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(4, random_state=2)
# Out:
#             job_title_short  \
# 631903         Data Analyst
# 675347     Business Analyst
# 246258  Senior Data Analyst
# 242366        Data Engineer
#
#                                                 job_title     job_location  \
# 631903                       Data Analyst Staff - Level 4   Fort Worth, TX
# 675347                 IT BUSINESS SYSTEMS ANALYST SENIOR   Birmingham, AL
# 246258  Senior Data Analyst, Business Intelligence (Mo...  Dublin, Ireland
# 242366                                      Data Engineer     Portland, OR
#
#                  job_via job_schedule_type  job_work_from_home  \
# 631903  via ZipRecruiter         Full-time               False
# 675347     via KFOR Jobs         Full-time               False
# 246258     via Hitmarker        Contractor               False
# 242366    via KHON2 Jobs         Full-time               False
#
#              search_location     job_posted_date  job_no_degree_mention  \
# ...

# %% [markdown]
# ## Practice Problems

# %%
df_org = df
df_copy = df.copy()

id(df_org), id(df_copy)
# Out:
# (1929909646352, 1929910031376)

# %%
df_copy['salary_year_avg'].dropna().head(5).sort_values(ascending=False)
# Out:
# 100    228222.0
# 77     140000.0
# 92     120000.0
# 28     109500.0
# 109     89000.0
# Name: salary_year_avg, dtype: float64

# %%
df_small_sample = df.copy()

df_small_sample.sample(frac = .1).head(5)
# Out:
#        job_title_short                                    job_title  \
# 284633   Data Engineer         Data Engineer | Python / SQL / Cloud
# 281833    Data Analyst                                 Data Analyst
# 561007    Data Analyst  Virtual Data Analyst / Entry level (Remote)
# 59181   Data Scientist             Data Scientist: Machine Learning
# 399146    Data Analyst                                 Data Analyst
#
#                                job_location        job_via job_schedule_type  \
# 284633  Capelle aan den IJssel, Netherlands     via Indeed         Full-time
# 281833                   Sweden  (+1 other)  via Wellfound         Full-time
# 561007                             Anywhere   via LinkedIn         Full-time
# 59181                         United States      via BeBee         Full-time
# 399146                     Oss, Netherlands     via Indeed         Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# ...

# %%
df_salary_update = df.copy()
salary_year_median = df['salary_year_avg'].median()

df_salary_update['salary_year_avg'] = df_salary_update['salary_year_avg'].fillna(salary_year_median)
df_salary_update.head(5)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...
